# %% [markdown]
# ![py-ss0.PNG](data:image/png;base64,...)

# %% [markdown]
# Take values of length and breadth of a rectangle from user and check if it is square or not.

# %%
print ("Enter length")
length = input()
print ("Enter breadth")
breadth = input()
if length == breadth:
  print ("Yes, it is square")
else:
  print ("No, it is only Rectangle")
# Out:
# Enter length
# 20
# Enter breadth
# 10
# No, it is only Rectangle

# %% [markdown]
# Take two int values from user and print greatest among them.

# %%
print ("Enter first number")
first = input()
print ("Enter second number")
second = input()
if first>second:
  print ("Greatest is ",first)
elif second>first:
  print ("Greatest is ",second)
else:
  print ("Both are equal")
# Out:
# Enter first number
# 5
# Enter second number
# 5
# Both are equal

# %% [markdown]
# A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
print ("Enter quantity")
quantity = input()
quantity = int(quantity)
if (quantity*100) > 1000:
  print ("Cost is ",((quantity*100)-(.1*quantity*100)) )
else:
  print ("Cost is ",quantity*100)
# Out:
# Enter quantity
# 12
# Cost is  1080.0

# %% [markdown]
# A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
print ("Enter salary")
salary = int(input())
print ("Enter year of service")
yos = int(input())
if yos>5:
  print ("Bonus is ",.05*salary)
else:
  print ("No bonus")
# Out:
# Enter salary
# 6
# Enter year of service
# 7
# Bonus is  0.30000000000000004

# %% [markdown]
# A school has following rules for grading system:
# a. Below 25 - F
# b. 25 to 45 - E
# c. 45 to 50 - D
# d. 50 to 60 - C
# e. 60 to 80 - B
# f. Above 80 - A
# Ask user to enter marks and print the corresponding grade.

# %%
print ("Enter marks")
marks = int(input())
if marks<25:
  print ("F")
elif marks>=25 and marks<45:
  print ("E")
elif marks>=45 and marks<50:
  print ("D")
elif marks>=50 and marks<60:
  print ("C")
elif marks>=60 and marks<80:
  print ("B")
else:
  print ("A")
# Out:
# Enter marks
# 88
# A

# %% [markdown]
# Take input of age of 3 people by user and determine oldest and youngest among them

# %%
print ("Enter first age")
first = int(input())
print ("Enter second age")
second = int(input())
print ("third age")
third = int(input())

if first >= second and first >= third:
  print ("Oldest is ",first)
elif second >= first and second >= third:
  print ("Oldest is ",second)
elif third >= first and third >= second:
  print ("Oldest is ",third)
else:
  print ("All are equal")
# Out:
# Enter first age
# 13
# Enter second age
# 14
# third age
# 5
# Oldest is  14

# %% [markdown]
# Write a program to print absolute vlaue of a number entered by user. E.g.-
# INPUT: 1        OUTPUT: 1
# INPUT: -1        OUTPUT: 1

# %%
print ("Enter a number")
number = int(input())
if number<0:
  print (number*-1)
else:
  print (number)
# Out:
# Enter a number
# -40
# 40

# %% [markdown]
# A student will not be allowed to sit in exam if his/her attendence is less than 75%.
# Take following input from user
# Number of classes held
# Number of classes attended.
# And print
# percentage of class attended
# Is student is allowed to sit in exam or not.

# %%
print ("Number of classes held")
noh = int(input())
print ("Number of classes attended")
noa = int(input())
atten = (noa/float(noh))*100
print ("Attendence is ",atten)
if atten >= 75:
  print ("You are allowed to sit in exam")
else:
  print ("Sorry, you are not allowed. Attend more classes from next time.")
# Out:
# Number of classes held
# 100
# Number of classes attended
# 89
# Attendence is  89.0
# You are allowed to sit in exam

# %% [markdown]
# Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
print ("Number of classes held")
noh = int(input())
print ("Number of classes attended")
noa = int(input())
atten = (noa/float(noh))*100
print ("Attendence is ",atten)
print("Do you have a medical cause (Answet Y or N )")
medical_cause = input()
if atten >= 75:
  print ("You are allowed to sit in exam")
else:
  if medical_cause == 'Y':
     print ("You are allowed")
  else:
     print ("Sorry, you are not allowed. Attend more classes from next time.")
# Out:
# Number of classes held
# 50
# Number of classes attended
# 25
# Attendence is  50.0
# Do you have a medical cause (Answet Y or N )
# Y
# You are allowed

# %% [markdown]
# A shop will give discount of 5% if the cost of purchased quantity is more than 500, 10% if the cost of purchased quantity is more than 1000 other wise 15 % if quantity is more than 2000.
#  For some given quantityJudge and print total cost for user.

# %%
print("Enter the cost of purchased item")
cost = int(input())
if(cost > 2000):
  print("You got 15% dicsount & you have to pay ", (cost - .15*cost))
elif (cost > 1000):
  print("You got 5% dicsount & you have to pay ", (cost - .1*cost))
elif (cost > 500):
  print("You got 5% dicsount & you have to pay ", (cost - .05*cost))
else: 
  print("COST = ", cost)
# Out:
# Enter the cost of purchased item
# 200
# COST =  200

# %%
print("Enter the cost of purchased item")
cost = int(input())
if(cost > 2000):
  print("You got 15% dicsount & you have to pay ", (cost - .15*cost))
elif (cost > 1000):
  print("You got 5% dicsount & you have to pay ", (cost - .1*cost))
elif (cost > 500):
  print("You got 5% dicsount & you have to pay ", (cost - .05*cost))
else: 
  print("COST = ", cost)
# Out:
# Enter the cost of purchased item
# 3000
# You got 15% dicsount & you have to pay  2550.0

# %%
print("Enter a number")
num = int(input())
if num%2 == 0:
  print("EVEN number")
else: 
  print("ODD number")
# Out:
# Enter a number
# 49
# ODD number

# %%
print("Enter a number")
num = int(input())
if num%2 == 0:
  print("EVEN number")
else: 
  print("ODD number")
# Out:
# Enter a number
# 20
# EVEN number

# %% [markdown]
# Write a program to check if a year is leap year or not.

# %%
year=int(input("Enter year to be checked:"))
if(year%4==0 and year%100!=0 or year%400==0):
    print("The year is a leap year!")
else:
    print("The year isn't a leap year!")
# Out:
# Enter year to be checked:2020
# The year is a leap year!

# %% [markdown]
#  Ask user to enter age, sex ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR".

# %%
print("Enter Sex")
G = input()
print("Marital Status")
M = input()
print("Enter Age")
age = int(input())

if G == 'F':
  print("You can work only in urban areas")
else:
   if (age > 20 and age < 40 ):
     print("You may work anywhere")
   elif (age > 40 and age < 60):
     print("You can work only in urban areas")
   else:
     print("ERROR")
# Out:
# Enter Sex
# F
# Marital Status
# N
# Enter Age
# 47
# You can work only in urban areas

# %%
print("Enter Sex")
G = input()
print("Marital Status")
M = input()
print("Enter Age")
age = int(input())

if G == 'F':
  print("You can work only in urban areas")
else:
   if (age > 20 and age < 40 ):
     print("You may work anywhere")
   elif (age > 40 and age < 60):
     print("You can work only in urban areas")
   else:
     print("ERROR")
# Out:
# Enter Sex
# M
# Marital Status
# M
# Enter Age
# 32
# You may work anywhere

# %%
print("enter a number") 
n = int(input())
rev = 0
  
while(n > 0): 
    a = n % 10
    rev = rev * 10 + a 
    n = n // 10
      
print(rev)
# Out:
# enter a number
# 12345
# 54321
