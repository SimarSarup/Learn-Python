# %%
'hi'> 'hello' and 'byte' < 'Bye'
# Out:
# False

# %%
'hi' >'hello' or 'bye' < 'Bye'
# Out:
# True

# %%
7 > 8 or 5 < 6 and 'I am fine' > 'I am not fine'
# Out:
# False

# %%
10!=9 and 29 >= 29
# Out:
# True

# %%
10 != 9 and 29 >=29 and 'hi' > 'hello' or 'bye' < 'Bye' and 7 <= 2.5
# Out:
# True

# %%
5 % 10 + 10 < 50 and 29 >= 29
# Out:
# True

# %%
7 ** 2 <= 5 // 9 % 3 or 'bye' <'Bye'
# Out:
# False

# %%
7 / 4 < 6 and 'I am fine' > 'I am not fine'
# Out:
# False

# %%
10 + 6 * 2 ** 2 != 9 // 4 - 3  and 29 >= 29 / 9
# Out:
# True

# %%
'hello' * 5 > 'hello' or 'bye' < 'Bye'
# Out:
# True

# %%
15 & 22
# Out:
# 6

# %%
15 | 22
# Out:
# 31

# %%
-15 & 22
# Out:
# 16

# %%
-15 | 22
# Out:
# -9

# %%
~15
# Out:
# -16

# %%
~22
# Out:
# -23

# %%
~-20
# Out:
# 19

# %%
15 ^ 22
# Out:
# 25

# %%
8 << 3
# Out:
# 64

# %%
40 >> 3
# Out:
# 5

# %% [markdown]
#  = is assignment operator <br>
#  == is relational operator

# %%
a = 4
print(a)
# Out:
# 4

# %%
b = 3
print( a == b)
# Out:
# False

# %% [markdown]
# '/' is used for division <br>
# '*' is used for multiplication

# %%
4 /4
# Out:
# 1.0

# %%
4 * 4
# Out:
# 16

# %% [markdown]
# / is division operator <br>
# // is floor division operator

# %%
15 / 2
# Out:
# 7.5

# %%
15 // 2
# Out:
# 7

# %%
225 / 10
# Out:
# 22.5

# %%
225 // 10
# Out:
# 22

# %% [markdown]
# ' * ' is multiplication operator<br>
# ' ** ' is exponentiation operator

# %%
2 * 5
# Out:
# 10

# %%
2 ** 5
# Out:
# 32

# %%
a =6

# %%
a == 6
# Out:
# True

# %%
a <5.9
# Out:
# False

# %%
a > 5.9
# Out:
# True

# %%
b = 7

# %%
 b/ 6
# Out:
# 1.1666666666666667

# %%
b // 6
# Out:
# 1

# %%
b / 4
# Out:
# 1.75

# %%
b % 4
# Out:
# 3

# %%
b * 7
# Out:
# 49

# %%
b % 7
# Out:
# 0

# %%
b * 2
# Out:
# 14

# %%
b ** 2
# Out:
# 49
